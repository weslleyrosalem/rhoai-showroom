# %% [markdown]
# # Distributed task training with Ray
# The job uses two CPU worker pods. Per-SKU task parallelism is different from gradient DDP. Submit through the authenticated terminal. Completed jobs are not automatically recreated by GitOps.

# %%
from pathlib import Path
repo=Path.cwd()
if repo.name == "notebooks": repo=repo.parent
print((repo/"gitops/components/science/rayjob.yaml").read_text())

# %%
# From an authenticated presenter terminal at the repository root:
# python scripts/science.py ray-submit
# oc get rayjobs,rayclusters,pods -n ai-showroom
# The notebook service account does not receive cluster management privileges.
