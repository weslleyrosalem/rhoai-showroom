# %% [markdown]
# # Treinamento distribuído por tarefas com Ray
# O job usa dois workers CPU. Não confundir este paralelismo por SKU com DDP de gradientes.
# Submeta o manifesto pelo terminal autenticado. Execuções concluídas não são recriadas por GitOps.

# %%
from pathlib import Path
repo=Path.cwd()
if repo.name == "notebooks": repo=repo.parent
print((repo/"gitops/components/science/rayjob.yaml").read_text())

# %%
# No terminal autenticado do apresentador, na raiz do repositório:
# oc create -f gitops/components/science/rayjob.yaml
# oc get rayjobs,rayclusters,pods -n ai-showroom
# O ServiceAccount do notebook não recebe permissão de gerenciamento de cluster.
